# %% [markdown]
# # 使用2022年的数据训练决策树
#
# 2022年的主要改动在于：提供了非常多的固定动量p的正电子的模拟数据，并且没有给出波形，而是给出了PETime。后者是一个好消息，意味着2021年的手作算法彻底退出舞台。
# 这里我们先按照去年一样的特征工程，即五个特征：
#
# 1. 单个事件的PE总数；
# 2. 单个事件，对于每个有PE的PMT，每个PMT会对应一个PE数。每个事件都有一个这样的序列，这个序列的平均值；
# 3. 2中序列的标准差；
# 4. 单个事件，对于每个有PE的PMT，每个PMT会对应一系列PETime。先对单个PMT进行PETime平均，然后这个PETime平均对于每个PMT构成一个序列，这个序列的平均值；
# 5. 4中序列的标准差。
#
# 今年没有暗噪声，因此代码会相当直接。

# %%
import numpy as np
import h5py
import lightgbm as lgb
from tqdm import tqdm
import multiprocessing

# %% [markdown]
# ## 读取数据集
# 我们可能需要区分固定动量正电子和非固定动量正电子的训练数据，因此这里分开读。为了保持与去年的一致性，分开读之后会合并起来。

# %%
# 含有10000的是固定动量正电子的数据
# 结果证明固定动量也不是完全固定，可能是因为误差
event_count_10000 = np.empty(11, dtype=int)
PETruth_entries_10000 = np.empty(11, dtype=int)
for data_id in range(11):
    with h5py.File(f'data-2022/{data_id}-10000-exact.h5', 'r') as data_file:
        event_count_10000[data_id] = data_file['ParticleTruth'].shape[0]
        PETruth_entries_10000[data_id] = data_file['PETruth'].shape[0]


p_10000 = np.empty(event_count_10000.sum())

event_count_index_10000 = np.insert(np.cumsum(event_count_10000), 0, 0)
PETruth_entries_index_10000 = np.insert(np.cumsum(PETruth_entries_10000), 0, 0)

PETruth_10000 = np.empty(PETruth_entries_10000.sum(), dtype=[('EventID', '<i4'), ('ChannelID', '<i4'), ('PETime', '<f8')])
for data_id in tqdm(range(11)):
    with h5py.File(f'data-2022/{data_id}-10000-exact.h5', 'r') as data_file:
        p_10000[event_count_index_10000[data_id]:event_count_index_10000[data_id+1]] = data_file['ParticleTruth']['p'][...]

        single_PETruth = data_file['PETruth'][...]
        previous_events = event_count_index_10000[data_id]
        single_PETruth['EventID'] += previous_events
        PETruth_10000[PETruth_entries_index_10000[data_id]:PETruth_entries_index_10000[data_id+1]] = single_PETruth
# Out:
# 100%|██████████| 11/11 [01:59<00:00, 10.86s/it]

# %%
# 不含有10000的是随机动量正电子的数据
event_count = np.empty(20, dtype=int)
PETruth_entries = np.empty(20, dtype=int)
for data_id in range(20):
    with h5py.File(f'data-2022/{data_id}-exact.h5', 'r') as data_file:
        event_count[data_id] = data_file['ParticleTruth'].shape[0]
        PETruth_entries[data_id] = data_file['PETruth'].shape[0]


p = np.empty(event_count.sum())

event_count_index = np.insert(np.cumsum(event_count), 0, 0)
PETruth_entries_index = np.insert(np.cumsum(PETruth_entries), 0, 0)

PETruth = np.empty(PETruth_entries.sum(), dtype=[('EventID', '<i4'), ('ChannelID', '<i4'), ('PETime', '<f8')])
for data_id in tqdm(range(20)):
    with h5py.File(f'data-2022/{data_id}-exact.h5', 'r') as data_file:
        p[event_count_index[data_id]:event_count_index[data_id+1]] = data_file['ParticleTruth']['p'][...]

        single_PETruth = data_file['PETruth'][...]
        previous_events = event_count_index[data_id]
        single_PETruth['EventID'] += previous_events
        PETruth[PETruth_entries_index[data_id]:PETruth_entries_index[data_id+1]] = single_PETruth
# Out:
# 100%|██████████| 20/20 [01:58<00:00,  5.91s/it]

# %% [markdown]
# 笑死，这样也太占内存了。其实我们完全没有必要把东西都读出来，边读边处理它不香吗？
# ## 数据处理，得到五个特征

# %%
# 先看看训练集到底有多少个事件
# 我们总共有31个训练集，11个固定动量，20个随机动量。这些就hard-code了

event_count = np.zeros(31, dtype=int)

for data_id in range(11):
    with h5py.File(f'data-2022/{data_id}-10000-exact.h5', 'r') as data_file:
        event_count[data_id] = data_file['ParticleTruth'].shape[0]

for data_id in range(20):
    with h5py.File(f'data-2022/{data_id}-exact.h5', 'r') as data_file:
        event_count[data_id+11] = data_file['ParticleTruth'].shape[0]

event_total = event_count.sum()
print(f'训练集一共有{event_total}个事件')
# Out:
# 训练集一共有310000个事件

# %% [markdown]
# 好的，我们看到这次的训练集没有像去年一样整什么“事件消失术”。接下来直接上特征。
#
# `PE_total`: 单次事件的PE总数
#
# `PE_mean`: 单次事件所有有PE的PMT的PE数平均值
#
# `PE_std`: 单次事件所有有PE的PMT的PE数标准差
#
# `PETime_mean`: 单次事件，PETime对单个PMT取平均值，再对所有有PE的PMT取平均值
#
# `PETime_std`: 单次事件，PETime对单个PMT取平均值，再对所有有PE的PMT取标准差

# %%
# 训练目标
p_train = np.zeros(event_total)

# 特征
PE_total_train = np.zeros(event_total, dtype='<i4')
PE_mean_train = np.zeros(event_total, dtype='<f8')
PE_std_train = np.zeros(event_total, dtype='<f8')
PETime_mean_train= np.zeros(event_total, dtype='<f8')
PETime_std_train = np.zeros(event_total, dtype='<f8')

# %%
event_index_total = np.insert(np.cumsum(event_count), 0, 0)

for data_id in range(11):
    with h5py.File(f'data-2022/{data_id}-10000-exact.h5', 'r') as data_file:
        p_train[event_index_total[data_id]:event_index_total[data_id+1]] = data_file['ParticleTruth']['p'][...]

        PETruth = data_file['PETruth'][...]

        # 先按照event分组，得到PE总数
        event_ids, event_indices, event_PE_counts = np.unique(PETruth['EventID'], return_index=True, return_counts=True)
        PE_total_train[event_index_total[data_id]:event_index_total[data_id+1]] = event_PE_counts

        # 分组过后，分单个event进行处理
        event_indices = np.append(event_indices, PETruth.shape[0]+1)

        # 定义一个函数，用于多线程处理单个事件。每个线程是独立的，只是给一个数组赋值，没有输出
        def deal_with_events(event_id):
            event_PETruth = PETruth[event_indices[event_id]:event_indices[event_id+1]]

            # 对ChannelID再次进行分组
            channel_ids, channel_inverse, channel_PE_counts = np.unique(event_PETruth['ChannelID'], return_inverse=True, return_counts=True)

            # 得到PE_mean_train与PE_std_train
            PE_mean_train_single = channel_PE_counts.mean()
            PE_std_train_single = channel_PE_counts.std()

            # 拿出单个channel的信息
            channel_PETime_mean = np.zeros(channel_ids.shape[0])
            # channel_indices = np.append(channel_indices, channel_ids.shape[0]+1)
            for channel_number in range(channel_ids.shape[0]):
                channel_PETime_mean[channel_number] = event_PETruth['PETime'][
                    channel_inverse == channel_number
                ].mean()
            
            # 得到PETime_mean_train与PETime_std_train
            PETime_mean_train_single = channel_PETime_mean.mean()
            PETime_std_train_single = channel_PETime_mean.std()

            return PE_mean_train_single, PE_std_train_single, PETime_mean_train_single, PETime_std_train_single
        
        with multiprocessing.Pool(20) as p:
            res = np.array(list(tqdm(p.imap(deal_with_events, event_ids), total=event_ids.shape[0])))
            PE_mean_train[event_index_total[data_id]:event_index_total[data_id+1]] = res[:, 0]
            PE_std_train[event_index_total[data_id]:event_index_total[data_id+1]] = res[:, 1]
            PETime_mean_train[event_index_total[data_id]:event_index_total[data_id+1]] = res[:, 2]
            PETime_std_train[event_index_total[data_id]:event_index_total[data_id+1]] = res[:, 3]
        
for data_id in range(20):
    with h5py.File(f'data-2022/{data_id}-exact.h5', 'r') as data_file:
        p_train[event_index_total[data_id+11]:event_index_total[data_id+12]] = data_file['ParticleTruth']['p'][...]

        PETruth = data_file['PETruth'][...]

        # 先按照event分组，得到PE总数
        event_ids, event_indices, event_PE_counts = np.unique(PETruth['EventID'], return_index=True, return_counts=True)
        PE_total_train[event_index_total[data_id+11]:event_index_total[data_id+12]] = event_PE_counts

        # 分组过后，分单个event进行处理
        event_indices = np.append(event_indices, PETruth.shape[0]+1)

        # 定义一个函数，用于多线程处理单个事件。每个线程是独立的，只是给一个数组赋值，没有输出
        def deal_with_events(event_id):
            event_PETruth = PETruth[event_indices[event_id]:event_indices[event_id+1]]

            # 对ChannelID再次进行分组
            channel_ids, channel_inverse, channel_PE_counts = np.unique(event_PETruth['ChannelID'], return_inverse=True, return_counts=True)

            # 得到PE_mean_train与PE_std_train
            PE_mean_train_single = channel_PE_counts.mean()
            PE_std_train_single = channel_PE_counts.std()

            # 拿出单个channel的信息
            channel_PETime_mean = np.zeros(channel_ids.shape[0])
            # channel_indices = np.append(channel_indices, channel_ids.shape[0]+1)
            for channel_number in range(channel_ids.shape[0]):
                channel_PETime_mean[channel_number] = event_PETruth['PETime'][
                    channel_inverse == channel_number
                ].mean()
            
            # 得到PETime_mean_train与PETime_std_train
            PETime_mean_train_single = channel_PETime_mean.mean()
            PETime_std_train_single = channel_PETime_mean.std()

            return PE_mean_train_single, PE_std_train_single, PETime_mean_train_single, PETime_std_train_single
        
        with multiprocessing.Pool(20) as p:
            res = np.array(list(tqdm(p.imap(deal_with_events, event_ids), total=event_ids.shape[0])))
            PE_mean_train[event_index_total[data_id+11]:event_index_total[data_id+12]] = res[:, 0]
            PE_std_train[event_index_total[data_id+11]:event_index_total[data_id+12]] = res[:, 1]
            PETime_mean_train[event_index_total[data_id+11]:event_index_total[data_id+12]] = res[:, 2]
            PETime_std_train[event_index_total[data_id+11]:event_index_total[data_id+12]] = res[:, 3]
# Out:
# 100%|██████████| 10000/10000 [00:10<00:00, 949.07it/s]
# 100%|██████████| 10000/10000 [00:21<00:00, 471.11it/s]
# 100%|██████████| 10000/10000 [00:32<00:00, 307.43it/s]
# 100%|██████████| 10000/10000 [00:44<00:00, 224.96it/s]
# 100%|██████████| 10000/10000 [00:56<00:00, 177.12it/s]
# 100%|██████████| 10000/10000 [01:09<00:00, 143.11it/s]
# 100%|██████████| 10000/10000 [01:22<00:00, 121.68it/s]
# 100%|██████████| 10000/10000 [01:34<00:00, 105.84it/s]
# 100%|██████████| 10000/10000 [01:49<00:00, 91.28it/s]
# 100%|██████████| 10000/10000 [02:02<00:00, 81.38it/s]
# 100%|██████████| 10000/10000 [02:17<00:00, 72.96it/s]
# 100%|██████████| 10000/10000 [00:38<00:00, 258.92it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 264.71it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 265.83it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 264.38it/s]
# 100%|██████████| 10000/10000 [00:38<00:00, 262.62it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 265.07it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 267.04it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 265.68it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 268.70it/s]
# 100%|██████████| 10000/10000 [00:36<00:00, 271.21it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 268.60it/s]
# 100%|██████████| 10000/10000 [00:38<00:00, 262.22it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 268.06it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 265.99it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 269.94it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 263.31it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 269.91it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 268.09it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 267.79it/s]
# 100%|██████████| 10000/10000 [00:37<00:00, 266.56it/s]

# %% [markdown]
# 存储一下得到的特征工程

# %%
char_dtype = np.dtype(
    [
        ('PE_total', '<i4'),
        ('PE_mean', '<f8'),
        ('PE_std', '<f8'),
        ('PETime_mean', '<f8'),
        ('PETime_std', '<f8'),
        ('p', '<f8')
    ]
)

char_data = np.zeros(p_train.shape, dtype=char_dtype)
char_data['PE_total'] = PE_total_train
char_data['PE_mean'] = PE_mean_train
char_data['PE_std'] = PE_std_train
char_data['PETime_mean'] = PETime_mean_train
char_data['PETime_std'] = PETime_std_train
char_data['p'] = p_train

with h5py.File(f'train-2022/character.h5', 'a') as char_file:
    char_file.create_dataset("characters", data=char_data)

# %% [markdown]
# ## 训练模型
# 我们使用Lightgbm直接训练一个到p的决策树。先写一个损失函数：

# %%
def lossfunc_eval(y, data):
    '''
    lossfunc_eval: 用平台的评分标准来评估决策树
    '''
    momentum_true = data.get_label()
    mass = 0.511
    energy_true = np.sqrt(momentum_true**2+mass**2)
    energy_y = np.sqrt(y**2+mass**2)

    loss = (energy_y - energy_true) ** 2 / energy_true
    return "resolution", np.mean(loss), False

def lossfunc_train(y, data):
    '''
    lossfunc_train: 用平台的评分标准算梯度与hessian矩阵
    '''
    momentum_true = data.get_label()
    mass = 0.511
    energy_true = np.sqrt(momentum_true**2+mass**2)
    energy_y = np.sqrt(y**2+mass**2)

    grad = 2*(y-y*np.sqrt(momentum_true**2+mass**2)/np.sqrt(y**2+mass**2)) / energy_true
    hess = 2*(1 - y*energy_true/energy_y)/ energy_true
    return grad, hess

# %%
train_data_p = lgb.Dataset(
    np.stack(
        (PE_total_train[:-30000], PE_mean_train[:-30000], PE_std_train[:-30000], PETime_mean_train[:-30000], PETime_std_train[:-30000]),
        axis=1
    ),
    label=p_train[:-30000]
)

validation_data_p = lgb.Dataset(
    np.stack(
        (PE_total_train[-30000:], PE_mean_train[-30000:], PE_std_train[-30000:], PETime_mean_train[-30000:], PETime_std_train[-30000:]),
        axis=1
    ),
    label=p_train[-30000:],
    reference=train_data_p
)

params = {
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'resolution'},
    'num_leaves': 2**10,
    'learning_rate': 0.01,
    'feature_fraction': 1,
    'bagging_fraction': 1,
    'bagging_freq': 5,
    'verbose': 0,
    'num_threads': 20,
    'max_depth': 10,
}

gbmForP = lgb.train(
    params,
    train_data_p,
    num_boost_round=60000,
    valid_sets=validation_data_p,
    early_stopping_rounds=1000,
    # fobj=lossfunc_train,
    feval=lossfunc_eval
)
gbmForP.save_model('./model/model-2022.txt')
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004244 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's resolution: 1.65164
# Training until validation scores don't improve for 1000 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's resolution: 1.61805
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's resolution: 1.58514
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's resolution: 1.55289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's resolution: 1.5213
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's resolution: 1.49035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's resolution: 1.46002
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's resolution: 1.43031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's resolution: 1.4012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's resolution: 1.37269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's resolution: 1.34474
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's resolution: 1.31737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's resolution: 1.29054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's resolution: 1.26427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's resolution: 1.23852
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's resolution: 1.2133
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's resolution: 1.18859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's resolution: 1.16438
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's resolution: 1.14066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's resolution: 1.11743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's resolution: 1.09466
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's resolution: 1.07236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's resolution: 1.05051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's resolution: 1.0291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's resolution: 1.00813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's resolution: 0.987587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's resolution: 0.967461
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's resolution: 0.947738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's resolution: 0.928418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's resolution: 0.909488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's resolution: 0.890946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's resolution: 0.872784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's resolution: 0.854986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's resolution: 0.837549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's resolution: 0.82047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's resolution: 0.803738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's resolution: 0.787347
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's resolution: 0.771287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's resolution: 0.755555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's resolution: 0.740145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's resolution: 0.725049
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's resolution: 0.710255
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's resolution: 0.695767
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's resolution: 0.681576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's resolution: 0.667671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's resolution: 0.654052
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's resolution: 0.640708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's resolution: 0.627634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's resolution: 0.614828
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's resolution: 0.602282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's resolution: 0.589991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's resolution: 0.577955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's resolution: 0.566158
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's resolution: 0.554604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's resolution: 0.543287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's resolution: 0.532201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's resolution: 0.521337
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's resolution: 0.510699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's resolution: 0.500278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's resolution: 0.490068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's resolution: 0.480069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's resolution: 0.470272
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's resolution: 0.460678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's resolution: 0.451275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's resolution: 0.442068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's resolution: 0.43305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's resolution: 0.424209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's resolution: 0.415553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's resolution: 0.407077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's resolution: 0.398771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's resolution: 0.390636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's resolution: 0.382665
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's resolution: 0.374862
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's resolution: 0.367212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's resolution: 0.359726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's resolution: 0.352388
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's resolution: 0.345202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's resolution: 0.338164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's resolution: 0.331266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's resolution: 0.324509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's resolution: 0.317894
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's resolution: 0.311414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's resolution: 0.305065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's resolution: 0.298846
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's resolution: 0.292754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's resolution: 0.28679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's resolution: 0.280944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's resolution: 0.27522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's resolution: 0.269614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's resolution: 0.26412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's resolution: 0.258739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's resolution: 0.253469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's resolution: 0.248305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's resolution: 0.24325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's resolution: 0.238297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's resolution: 0.233445
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's resolution: 0.228696
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's resolution: 0.224039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's resolution: 0.21948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's resolution: 0.215013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's resolution: 0.210639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's resolution: 0.206353
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's resolution: 0.202158
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's resolution: 0.198046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's resolution: 0.194021
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's resolution: 0.190079
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's resolution: 0.186215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's resolution: 0.182433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's resolution: 0.178727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's resolution: 0.175096
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's resolution: 0.171541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's resolution: 0.168061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's resolution: 0.164649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's resolution: 0.161309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's resolution: 0.158039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's resolution: 0.154833
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's resolution: 0.151695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's resolution: 0.148623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's resolution: 0.145611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's resolution: 0.142662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's resolution: 0.139773
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's resolution: 0.136944
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's resolution: 0.134174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's resolution: 0.13146
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's resolution: 0.128803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's resolution: 0.126199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's resolution: 0.123648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's resolution: 0.121152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's resolution: 0.118705
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's resolution: 0.116308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's resolution: 0.113961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's resolution: 0.111664
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's resolution: 0.109411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's resolution: 0.107207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's resolution: 0.105047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's resolution: 0.102933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's resolution: 0.100861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's resolution: 0.0988318
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's resolution: 0.0968435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's resolution: 0.0948982
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's resolution: 0.092992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's resolution: 0.0911254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's resolution: 0.089297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's resolution: 0.0875077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's resolution: 0.0857526
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's resolution: 0.0840339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's resolution: 0.0823502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's resolution: 0.0807031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's resolution: 0.0790893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's resolution: 0.0775091
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's resolution: 0.0759612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's resolution: 0.0744452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's resolution: 0.0729592
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's resolution: 0.0715044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's resolution: 0.0700802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's resolution: 0.0686851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's resolution: 0.0673191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	valid_0's resolution: 0.0659806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	valid_0's resolution: 0.0646689
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's resolution: 0.0633854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's resolution: 0.0621287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	valid_0's resolution: 0.060898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	valid_0's resolution: 0.0596917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's resolution: 0.0585103
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's resolution: 0.0573532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	valid_0's resolution: 0.05622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's resolution: 0.0551108
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	valid_0's resolution: 0.0540234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	valid_0's resolution: 0.0529586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's resolution: 0.0519166
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	valid_0's resolution: 0.0508955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's resolution: 0.0498952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid_0's resolution: 0.0489142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid_0's resolution: 0.0479545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid_0's resolution: 0.0470141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's resolution: 0.0460936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid_0's resolution: 0.0451913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid_0's resolution: 0.0443083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid_0's resolution: 0.0434431
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's resolution: 0.042596
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	valid_0's resolution: 0.0417658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's resolution: 0.0409532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid_0's resolution: 0.0401576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's resolution: 0.0393776
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's resolution: 0.0386142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's resolution: 0.0378663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's resolution: 0.0371338
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's resolution: 0.036417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's resolution: 0.0357145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid_0's resolution: 0.0350264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's resolution: 0.0343527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's resolution: 0.0336928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	valid_0's resolution: 0.0330465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's resolution: 0.0324137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's resolution: 0.0317934
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	valid_0's resolution: 0.0311859
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's resolution: 0.0305908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid_0's resolution: 0.030008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's resolution: 0.029437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's resolution: 0.0288785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's resolution: 0.0283306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	valid_0's resolution: 0.0277942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	valid_0's resolution: 0.027269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid_0's resolution: 0.0267545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	valid_0's resolution: 0.0262509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid_0's resolution: 0.0257578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's resolution: 0.0252744
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [208]	valid_0's resolution: 0.0248006
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's resolution: 0.0243367
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid_0's resolution: 0.0238829
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid_0's resolution: 0.0234378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212]	valid_0's resolution: 0.0230016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	valid_0's resolution: 0.0225749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid_0's resolution: 0.0221566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [215]	valid_0's resolution: 0.021747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	valid_0's resolution: 0.0213457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [217]	valid_0's resolution: 0.0209529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [218]	valid_0's resolution: 0.0205677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [219]	valid_0's resolution: 0.0201904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220]	valid_0's resolution: 0.0198212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	valid_0's resolution: 0.0194593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [222]	valid_0's resolution: 0.019105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [223]	valid_0's resolution: 0.018758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	valid_0's resolution: 0.0184182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	valid_0's resolution: 0.0180852
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	valid_0's resolution: 0.0177591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	valid_0's resolution: 0.0174407
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	valid_0's resolution: 0.0171279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	valid_0's resolution: 0.0168212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	valid_0's resolution: 0.0165218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid_0's resolution: 0.0162287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232]	valid_0's resolution: 0.0159405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid_0's resolution: 0.0156581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [234]	valid_0's resolution: 0.0153826
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's resolution: 0.0151128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's resolution: 0.0148485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's resolution: 0.0145896
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's resolution: 0.0143349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's resolution: 0.0140852
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's resolution: 0.0138419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's resolution: 0.0136035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's resolution: 0.0133686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's resolution: 0.0131393
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's resolution: 0.0129151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's resolution: 0.0126955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's resolution: 0.012479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's resolution: 0.0122673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's resolution: 0.0120602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's resolution: 0.0118568
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's resolution: 0.0116576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's resolution: 0.0114628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's resolution: 0.0112719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's resolution: 0.0110849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's resolution: 0.0109014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's resolution: 0.0107219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's resolution: 0.0105459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's resolution: 0.0103736
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's resolution: 0.0102045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's resolution: 0.0100394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's resolution: 0.00987725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's resolution: 0.00971824
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's resolution: 0.00956278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's resolution: 0.00941023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's resolution: 0.00926068
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's resolution: 0.00911465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's resolution: 0.0089711
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's resolution: 0.0088308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's resolution: 0.00869372
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's resolution: 0.00855886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's resolution: 0.00842651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's resolution: 0.00829668
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's resolution: 0.0081704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's resolution: 0.0080459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's resolution: 0.00792437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's resolution: 0.00780549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's resolution: 0.0076889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's resolution: 0.00757432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's resolution: 0.00746198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's resolution: 0.00735226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's resolution: 0.00724467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's resolution: 0.0071395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's resolution: 0.00703619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's resolution: 0.00693512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's resolution: 0.00683601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's resolution: 0.0067389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's resolution: 0.00664356
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's resolution: 0.00655033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's resolution: 0.00645908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's resolution: 0.00636942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's resolution: 0.00628171
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's resolution: 0.00619593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's resolution: 0.006112
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid_0's resolution: 0.00602963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's resolution: 0.00594849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's resolution: 0.00586936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid_0's resolution: 0.00579195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's resolution: 0.00571593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's resolution: 0.00564118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's resolution: 0.00556818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's resolution: 0.00549659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's resolution: 0.00542647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's resolution: 0.0053576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	valid_0's resolution: 0.00529023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's resolution: 0.00522396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's resolution: 0.00515919
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's resolution: 0.00509619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's resolution: 0.00503444
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	valid_0's resolution: 0.00497389
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	valid_0's resolution: 0.00491384
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [310]	valid_0's resolution: 0.00485566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	valid_0's resolution: 0.00479864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [312]	valid_0's resolution: 0.00474216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	valid_0's resolution: 0.0046875
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's resolution: 0.0046339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [315]	valid_0's resolution: 0.00458094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's resolution: 0.0045296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	valid_0's resolution: 0.00447927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's resolution: 0.0044299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's resolution: 0.00438095
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's resolution: 0.0043329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's resolution: 0.00428651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's resolution: 0.00424103
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's resolution: 0.0041965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's resolution: 0.00415275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's resolution: 0.00410929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's resolution: 0.00406739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's resolution: 0.00402616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's resolution: 0.00398569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	valid_0's resolution: 0.00394619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's resolution: 0.00390711
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's resolution: 0.00386917
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's resolution: 0.00383189
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's resolution: 0.00379553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's resolution: 0.00375924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's resolution: 0.00372363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's resolution: 0.0036887
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [337]	valid_0's resolution: 0.0036544
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's resolution: 0.00362137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's resolution: 0.00358845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's resolution: 0.00355694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's resolution: 0.00352547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's resolution: 0.0034945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's resolution: 0.00346417
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's resolution: 0.00343448
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [345]	valid_0's resolution: 0.00340546
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's resolution: 0.00337692
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's resolution: 0.00334938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's resolution: 0.00332243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	valid_0's resolution: 0.00329552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's resolution: 0.003269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's resolution: 0.00324309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's resolution: 0.00321758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's resolution: 0.00319265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's resolution: 0.00316881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355]	valid_0's resolution: 0.00314487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [356]	valid_0's resolution: 0.00312176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's resolution: 0.00309874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's resolution: 0.00307616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's resolution: 0.00305397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's resolution: 0.00303226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's resolution: 0.00301094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's resolution: 0.00299013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	valid_0's resolution: 0.00297023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's resolution: 0.00295055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's resolution: 0.00293113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's resolution: 0.00291241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's resolution: 0.00289333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's resolution: 0.0028749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's resolution: 0.00285699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	valid_0's resolution: 0.00283923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's resolution: 0.00282234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's resolution: 0.00280527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's resolution: 0.00278893
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's resolution: 0.00277261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's resolution: 0.00275655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's resolution: 0.00274114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's resolution: 0.00272557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's resolution: 0.00271046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's resolution: 0.00269604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's resolution: 0.00268147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's resolution: 0.00266754
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's resolution: 0.00265348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's resolution: 0.00263974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's resolution: 0.00262619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's resolution: 0.00261326
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's resolution: 0.0026008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's resolution: 0.00258822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's resolution: 0.0025757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's resolution: 0.00256343
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's resolution: 0.00255137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's resolution: 0.00253986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	valid_0's resolution: 0.00252894
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's resolution: 0.00251795
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's resolution: 0.00250727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's resolution: 0.00249657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's resolution: 0.00248582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's resolution: 0.00247536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's resolution: 0.00246507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's resolution: 0.00245545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's resolution: 0.00244554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's resolution: 0.00243594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's resolution: 0.00242673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [403]	valid_0's resolution: 0.00241748
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [404]	valid_0's resolution: 0.00240853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's resolution: 0.00239961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [406]	valid_0's resolution: 0.00239124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [407]	valid_0's resolution: 0.00238258
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408]	valid_0's resolution: 0.00237436
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [409]	valid_0's resolution: 0.00236656
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	valid_0's resolution: 0.0023587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [411]	valid_0's resolution: 0.0023508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [412]	valid_0's resolution: 0.0023435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [413]	valid_0's resolution: 0.00233593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [414]	valid_0's resolution: 0.00232867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [415]	valid_0's resolution: 0.0023212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	valid_0's resolution: 0.0023141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [417]	valid_0's resolution: 0.00230731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [418]	valid_0's resolution: 0.00230039
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [419]	valid_0's resolution: 0.00229373
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [420]	valid_0's resolution: 0.0022873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [421]	valid_0's resolution: 0.00228072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [422]	valid_0's resolution: 0.0022743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [423]	valid_0's resolution: 0.00226786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [424]	valid_0's resolution: 0.00226181
# ...
# [1711]	valid_0's resolution: 0.00201252
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1712]	valid_0's resolution: 0.00201256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1713]	valid_0's resolution: 0.00201256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1714]	valid_0's resolution: 0.00201236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1715]	valid_0's resolution: 0.00201237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1716]	valid_0's resolution: 0.00201236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1717]	valid_0's resolution: 0.00201236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1718]	valid_0's resolution: 0.00201235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1719]	valid_0's resolution: 0.00201235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1720]	valid_0's resolution: 0.00201234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1721]	valid_0's resolution: 0.00201235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1722]	valid_0's resolution: 0.00201237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1723]	valid_0's resolution: 0.00201236
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1724]	valid_0's resolution: 0.00201235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1725]	valid_0's resolution: 0.00201215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1726]	valid_0's resolution: 0.00201216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1727]	valid_0's resolution: 0.00201206
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1728]	valid_0's resolution: 0.00201277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1729]	valid_0's resolution: 0.00201298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1730]	valid_0's resolution: 0.00201297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1731]	valid_0's resolution: 0.00201298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1732]	valid_0's resolution: 0.002013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1733]	valid_0's resolution: 0.00201303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1734]	valid_0's resolution: 0.00201304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1735]	valid_0's resolution: 0.00201304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1736]	valid_0's resolution: 0.00201311
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1737]	valid_0's resolution: 0.00201305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1738]	valid_0's resolution: 0.00201302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1739]	valid_0's resolution: 0.00201303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1740]	valid_0's resolution: 0.00201307
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1741]	valid_0's resolution: 0.00201305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1742]	valid_0's resolution: 0.00201307
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1743]	valid_0's resolution: 0.00201346
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1744]	valid_0's resolution: 0.00201341
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1745]	valid_0's resolution: 0.00201365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1746]	valid_0's resolution: 0.00201349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1747]	valid_0's resolution: 0.00201348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1748]	valid_0's resolution: 0.00201349
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1749]	valid_0's resolution: 0.00201363
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1750]	valid_0's resolution: 0.00201369
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1751]	valid_0's resolution: 0.00201401
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1752]	valid_0's resolution: 0.00201428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1753]	valid_0's resolution: 0.00201446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1754]	valid_0's resolution: 0.00201466
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1755]	valid_0's resolution: 0.00201503
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1756]	valid_0's resolution: 0.00201527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1757]	valid_0's resolution: 0.0020153
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1758]	valid_0's resolution: 0.00201512
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1759]	valid_0's resolution: 0.002015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1760]	valid_0's resolution: 0.00201517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1761]	valid_0's resolution: 0.00201517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1762]	valid_0's resolution: 0.00201517
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1763]	valid_0's resolution: 0.00201537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1764]	valid_0's resolution: 0.00201593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1765]	valid_0's resolution: 0.00201583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1766]	valid_0's resolution: 0.00201583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1767]	valid_0's resolution: 0.00201583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1768]	valid_0's resolution: 0.00201575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1769]	valid_0's resolution: 0.00201578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1770]	valid_0's resolution: 0.00201578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1771]	valid_0's resolution: 0.00201579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1772]	valid_0's resolution: 0.00201581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1773]	valid_0's resolution: 0.00201583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1774]	valid_0's resolution: 0.00201585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1775]	valid_0's resolution: 0.00201597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1776]	valid_0's resolution: 0.00201597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1777]	valid_0's resolution: 0.00201581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1778]	valid_0's resolution: 0.00201582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1779]	valid_0's resolution: 0.00201585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1780]	valid_0's resolution: 0.00201581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1781]	valid_0's resolution: 0.0020158
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1782]	valid_0's resolution: 0.00201579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1783]	valid_0's resolution: 0.00201581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1784]	valid_0's resolution: 0.00201583
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1785]	valid_0's resolution: 0.00201584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1786]	valid_0's resolution: 0.00201598
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1787]	valid_0's resolution: 0.00201594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1788]	valid_0's resolution: 0.00201588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1789]	valid_0's resolution: 0.00201586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1790]	valid_0's resolution: 0.00201606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1791]	valid_0's resolution: 0.00201607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1792]	valid_0's resolution: 0.00201626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1793]	valid_0's resolution: 0.00201619
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1794]	valid_0's resolution: 0.00201638
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1795]	valid_0's resolution: 0.00201658
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1796]	valid_0's resolution: 0.00201661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1797]	valid_0's resolution: 0.00201681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1798]	valid_0's resolution: 0.00201685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1799]	valid_0's resolution: 0.00201702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1800]	valid_0's resolution: 0.00201705
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1801]	valid_0's resolution: 0.00201721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1802]	valid_0's resolution: 0.00201746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1803]	valid_0's resolution: 0.00201768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1804]	valid_0's resolution: 0.00201761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1805]	valid_0's resolution: 0.00201765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1806]	valid_0's resolution: 0.00201748
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1807]	valid_0's resolution: 0.00201793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1808]	valid_0's resolution: 0.00201811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1809]	valid_0's resolution: 0.00201815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1810]	valid_0's resolution: 0.00201815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1811]	valid_0's resolution: 0.0020186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1812]	valid_0's resolution: 0.0020186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1813]	valid_0's resolution: 0.00201865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1814]	valid_0's resolution: 0.00201912
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1815]	valid_0's resolution: 0.00201911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1816]	valid_0's resolution: 0.0020191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1817]	valid_0's resolution: 0.00201916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1818]	valid_0's resolution: 0.00201921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1819]	valid_0's resolution: 0.00201922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1820]	valid_0's resolution: 0.00201923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1821]	valid_0's resolution: 0.0020197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1822]	valid_0's resolution: 0.00201953
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1823]	valid_0's resolution: 0.00201958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1824]	valid_0's resolution: 0.00201963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1825]	valid_0's resolution: 0.00201969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1826]	valid_0's resolution: 0.00201968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1827]	valid_0's resolution: 0.00201969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1828]	valid_0's resolution: 0.00201969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1829]	valid_0's resolution: 0.00201956
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1830]	valid_0's resolution: 0.00201949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1831]	valid_0's resolution: 0.00201956
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1832]	valid_0's resolution: 0.0020196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1833]	valid_0's resolution: 0.0020196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1834]	valid_0's resolution: 0.00201959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1835]	valid_0's resolution: 0.00201963
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1836]	valid_0's resolution: 0.00201961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1837]	valid_0's resolution: 0.0020196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1838]	valid_0's resolution: 0.00201961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1839]	valid_0's resolution: 0.0020196
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1840]	valid_0's resolution: 0.00201965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1841]	valid_0's resolution: 0.0020197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1842]	valid_0's resolution: 0.0020197
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1843]	valid_0's resolution: 0.00201968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1844]	valid_0's resolution: 0.0020195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1845]	valid_0's resolution: 0.00201955
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1846]	valid_0's resolution: 0.00201943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1847]	valid_0's resolution: 0.00201943
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1848]	valid_0's resolution: 0.00201942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1849]	valid_0's resolution: 0.00201948
# Early stopping, best iteration is:
# [849]	valid_0's resolution: 0.00195792

# %% [markdown]
# ## 解题

# %%
with h5py.File(f'data-2022/problem.h5', 'r') as problem_file:

    PETruth = problem_file['PETruth'][...]

    # 先按照event分组，得到PE总数
    event_ids, event_indices, event_PE_counts = np.unique(PETruth['EventID'], return_index=True, return_counts=True)
    PE_total_problem = event_PE_counts

    # 分组过后，分单个event进行处理
    event_indices = np.append(event_indices, PETruth.shape[0]+1)

    # 定义一个函数，用于多线程处理单个事件。每个线程是独立的，只是给一个数组赋值，没有输出
    def deal_with_events(event_id):
        event_PETruth = PETruth[event_indices[event_id]:event_indices[event_id+1]]

        # 对ChannelID再次进行分组
        channel_ids, channel_inverse, channel_PE_counts = np.unique(event_PETruth['ChannelID'], return_inverse=True, return_counts=True)

        # 得到PE_mean_train与PE_std_train
        PE_mean_train_single = channel_PE_counts.mean()
        PE_std_train_single = channel_PE_counts.std()

        # 拿出单个channel的信息
        channel_PETime_mean = np.zeros(channel_ids.shape[0])
        # channel_indices = np.append(channel_indices, channel_ids.shape[0]+1)
        for channel_number in range(channel_ids.shape[0]):
            channel_PETime_mean[channel_number] = event_PETruth['PETime'][
                channel_inverse == channel_number
            ].mean()
        
        # 得到PETime_mean_train与PETime_std_train
        PETime_mean_train_single = channel_PETime_mean.mean()
        PETime_std_train_single = channel_PETime_mean.std()

        return PE_mean_train_single, PE_std_train_single, PETime_mean_train_single, PETime_std_train_single
    
    with multiprocessing.Pool(20) as p:
        res = np.array(list(tqdm(p.imap(deal_with_events, event_ids), total=event_ids.shape[0])))
        PE_mean_problem = res[:, 0]
        PE_std_problem = res[:, 1]
        PETime_mean_problem = res[:, 2]
        PETime_std_problem = res[:, 3]
# Out:
# 100%|██████████| 20000/20000 [01:50<00:00, 181.78it/s]

# %%
gbmForP = lgb.Booster(model_file='./model/model-2022.txt')

ans_p = gbmForP.predict(
    np.stack(
        (PE_total_problem, PE_mean_problem, PE_std_problem, PETime_mean_problem, PETime_std_problem),
        axis=1
    )
)

ans_dtype = np.dtype(
    [
        ('EventID', '<i4'),
        ('p', '<f8')
    ]
)

ans_data = np.zeros(ans_p.shape, dtype=ans_dtype)
ans_data['EventID'] = np.arange(ans_p.shape[0])
ans_data['p'] = ans_p


with h5py.File(f'ans-2022/ans_last_year.h5', 'a') as ans_file:
    ans_file.create_dataset("Answer", data=ans_data)

# %% [markdown]
# 这样评测平台给出的是0.039/0.01。
